# %% [markdown]
# https://www.kaggle.com/datasets/nanditapore/medical-cost-dataset

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.10/dist-packages (0.0.post9)

# %%
sklearn.__version__
# Out:
# '1.2.2'

# %% [markdown]
# #Intro to Pandas

# %% [markdown]
# ## Acessing the Data

# %%
import pandas as pd
import numpy

# %%
df = pd.read_csv("/content/medical_cost.csv",index_col= 'Id')

# %%
dict = {"Name": ["Rahul", "Shivani", "Hari"] ,
         "Marks" : [90, 89, 94]}

Data = pd.DataFrame(dict)
Data
# Out:
#       Name  Marks
# 0    Rahul     90
# 1  Shivani     89
# 2     Hari     94

# %% [markdown]
# **Native accessors**
#
# Native Python objects provide good ways of indexing data. Pandas carries all of these over, which helps make it easy to start with.
#
# Consider this DataFrame:

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# Id
# 1      19  female  27.900         0    yes  southwest  16884.92400
# 2      18    male  33.770         1     no  southeast   1725.55230
# 3      28    male  33.000         3     no  southeast   4449.46200
# 4      33    male  22.705         0     no  northwest  21984.47061
# 5      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1334   50    male  30.970         3     no  northwest  10600.54830
# 1335   18  female  31.920         0     no  northeast   2205.98080
# 1336   18  female  36.850         0     no  southeast   1629.83350
# 1337   21  female  25.800         0     no  southwest   2007.94500
# 1338   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## Viewing Data

# %% [markdown]
# To access a Specific column we can use two ways
#
# ```
# # df.columnname
# ```
#
#
# ```
# # df["columnname"]
# ```

# %%
df.age
# Out:
# Id
# 1       19
# 2       18
# 3       28
# 4       33
# 5       32
#         ..
# 1334    50
# 1335    18
# 1336    18
# 1337    21
# 1338    61
# Name: age, Length: 1338, dtype: int64

# %%
df['age']
# Out:
# Id
# 1       19
# 2       18
# 3       28
# 4       33
# 5       32
#         ..
# 1334    50
# 1335    18
# 1336    18
# 1337    21
# 1338    61
# Name: age, Length: 1338, dtype: int64

# %% [markdown]
# To acess the row you can add the row id in front of it with [ ]

# %%
df['age'][10]
# Out:
# 60

# %% [markdown]
# ## Indexing
# The indexing operator and attribute selection are nice because they work just like they do in the rest of the Python ecosystem. As a novice, this makes them easy to pick up and use. However, pandas has its own accessor operators, **loc** and **iloc**. For more advanced operations, these are the ones you're supposed to be using.
#
#
# 1.index-based selection:
#
#
#
# ```
# # df.iloc[rowid]
# ```
# 2.label-based selection:
#
#
# ```
# # df.loc[rowid, 'columnid']
# ```

# %%
df.iloc[0]
# Out:
# age                19
# sex            female
# bmi              27.9
# children            0
# smoker            yes
# region      southwest
# charges     16884.924
# Name: 1, dtype: object

# %% [markdown]
# now accessing is similar to string

# %%
df.iloc[:5]
# Out:
#     age     sex     bmi  children smoker     region      charges
# Id
# 1    19  female  27.900         0    yes  southwest  16884.92400
# 2    18    male  33.770         1     no  southeast   1725.55230
# 3    28    male  33.000         3     no  southeast   4449.46200
# 4    33    male  22.705         0     no  northwest  21984.47061
# 5    32    male  28.880         0     no  northwest   3866.85520

# %%
df.loc[:3, 'children']
# Out:
# Id
# 1    0
# 2    1
# 3    3
# Name: children, dtype: int64

# %%
df.loc[3, ['bmi',	'children',	'smoker']]
# Out:
# bmi         33.0
# children       3
# smoker        no
# Name: 3, dtype: object

# %% [markdown]
# ## Conditional selection

# %%
df.sex == "male"
# Out:
# Id
# 1       False
# 2        True
# 3        True
# 4        True
# 5        True
#         ...
# 1334     True
# 1335    False
# 1336    False
# 1337    False
# 1338    False
# Name: sex, Length: 1338, dtype: bool

# %%
df[df.sex == "male"]
# Out:
#       age   sex     bmi  children smoker     region      charges
# Id
# 2      18  male  33.770         1     no  southeast   1725.55230
# 3      28  male  33.000         3     no  southeast   4449.46200
# 4      33  male  22.705         0     no  northwest  21984.47061
# 5      32  male  28.880         0     no  northwest   3866.85520
# 9      37  male  29.830         2     no  northeast   6406.41070
# ...   ...   ...     ...       ...    ...        ...          ...
# 1325   31  male  25.935         1     no  northwest   4239.89265
# 1326   61  male  33.535         0     no  northeast  13143.33665
# 1328   51  male  30.030         1     no  southeast   9377.90470
# 1330   52  male  38.600         2     no  southwest  10325.20600
# 1334   50  male  30.970         3     no  northwest  10600.54830
#
# [676 rows x 7 columns]

# %%
df[(df.sex == "male") & (df.bmi >30)]
# Out:
#       age   sex     bmi  children smoker     region      charges
# Id
# 2      18  male  33.770         1     no  southeast   1725.55230
# 3      28  male  33.000         3     no  southeast   4449.46200
# 13     23  male  34.400         0     no  southwest   1826.84300
# 15     27  male  42.130         0    yes  southeast  39611.75770
# 19     56  male  40.300         0     no  southwest  10602.38500
# ...   ...   ...     ...       ...    ...        ...          ...
# 1323   62  male  38.830         0     no  southeast  12981.34570
# 1326   61  male  33.535         0     no  northeast  13143.33665
# 1328   51  male  30.030         1     no  southeast   9377.90470
# 1330   52  male  38.600         2     no  southwest  10325.20600
# 1334   50  male  30.970         3     no  northwest  10600.54830
#
# [371 rows x 7 columns]

# %% [markdown]
# ## Summary Functions and Sorting

# %% [markdown]
# **Describe**
#
# Gives a Statistical description of the data.
#
#
# ```
# # df.describe()
# ```
# **Unique**
#
# Returns unique values.
#
#
#
# ```
# # df.colname.unique()
# ```
#
# **value_counts**
#
# Returns number of unique values.
#
#
# ```
# # df.colname.valuecounts()
# ```
#
# **sort_values**
#
#
# sorts value of given column(can be multiple columns).
#
#
#
# ```
# # df.sort_values(by='column',, ascending=bool)
# ```

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df.region.value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
df.sort_values(by='region')
# Out:
#      age     sex     bmi  children smoker     region      charges
# Id
# 669   62    male  32.015         0    yes  northeast  45710.20785
# 320   32    male  37.335         1     no  northeast   4667.60765
# 845   53    male  30.495         0     no  northeast  10072.05505
# 318   54    male  32.775         0     no  northeast  10435.06525
# 316   52    male  33.250         0     no  northeast   9722.76950
# ..   ...     ...     ...       ...    ...        ...          ...
# 291   28  female  33.400         0     no  southwest   3172.01800
# 889   22    male  39.500         0     no  southwest   1682.59700
# 295   25    male  26.800         3     no  southwest   3906.12700
# 919   61  female  28.200         0     no  southwest  13041.92100
# 1     19  female  27.900         0    yes  southwest  16884.92400
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## Data Types and Missing Values
#
# **Info**
#
# Gives Breif about Dtypes.
#
# ```
# # df.info()
# ```
#
#
# **Check null values:**
# Returns number of null values.
#
# ```
# # df.isnull().sum()
# ```
# **Fill na**
# Helps in filling null values.
#
# ```
# # df.columnname.fillna("filling data", inplace = True)
# ```

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1338 entries, 1 to 1338
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 115.9+ KB

# %%
data = [
    ["John Doe", 30, 10000],
    [None, 25, 20000],
    ["Jane Doe", 20, 30000],
    [None, 40, 40000],
    ["Peter", 35, None],
]

MM = pd.DataFrame(data, columns=["Name", "Age", "Salary"])
MM
# Out:
#        Name  Age   Salary
# 0  John Doe   30  10000.0
# 1      None   25  20000.0
# 2  Jane Doe   20  30000.0
# 3      None   40  40000.0
# 4     Peter   35      NaN

# %%
MM.isnull().sum()
# Out:
# Name      2
# Age       0
# Salary    1
# dtype: int64

# %%
MM.Name.fillna("No_Name")
# Out:
# 0    John Doe
# 1     No_Name
# 2    Jane Doe
# 3     No_Name
# 4       Peter
# Name: Name, dtype: object

# %%
MM.Salary.fillna(method ='ffill')
# Out:
# 0    10000.0
# 1    20000.0
# 2    30000.0
# 3    40000.0
# 4    40000.0
# Name: Salary, dtype: float64

# %% [markdown]
# Although It is filling but the data is not saved, So to that we need to use inplace as well

# %%
MM.Salary.fillna(method ='ffill', inplace = True)

# %%
df.rename(columns={'charges': 'Cost'}, inplace = True)
df
# Out:
#       age     sex     bmi  children smoker     region         Cost
# Id
# 1      19  female  27.900         0    yes  southwest  16884.92400
# 2      18    male  33.770         1     no  southeast   1725.55230
# 3      28    male  33.000         3     no  southeast   4449.46200
# 4      33    male  22.705         0     no  northwest  21984.47061
# 5      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1334   50    male  30.970         3     no  northwest  10600.54830
# 1335   18  female  31.920         0     no  northeast   2205.98080
# 1336   18  female  36.850         0     no  southeast   1629.83350
# 1337   21  female  25.800         0     no  southwest   2007.94500
# 1338   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # Preprocessing

# %% [markdown]
# 1. First step is  Identifying Your Data Type and the making the required chages to it so that your model can understand and process the data.
#
# 2. Your model can only take in numeric data so you will need to change the data to numeric data.
#
# So what changes will you make to the following data?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1338 entries, 1 to 1338
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   Cost      1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 115.9+ KB

# %%
for i in df.columns:
  print(f"Column {i} has {df[i].nunique()} values.")
# Out:
# Column age has 47 values.
# Column sex has 2 values.
# Column bmi has 548 values.
# Column children has 6 values.
# Column smoker has 2 values.
# Column region has 4 values.
# Column Cost has 1337 values.

# %% [markdown]
# ## Categorical features:
#
# When To use **Label encoder**  & **Onehot-encoding**
#
#
# ```
# # pandas.get_dummies(data)
# ```
#
#
# ```
# # label_encoder = preprocessing.LabelEncoder()
#
# df[Colname]= label_encoder.fit_transform(df[Colname])
# ```

# %%
cat = df.select_dtypes(include = object)
cat
# Out:
#          sex smoker     region
# Id
# 1     female    yes  southwest
# 2       male     no  southeast
# 3       male     no  southeast
# 4       male     no  northwest
# 5       male     no  northwest
# ...      ...    ...        ...
# 1334    male     no  northwest
# 1335  female     no  northeast
# 1336  female     no  southeast
# 1337  female     no  southwest
# 1338  female    yes  northwest
#
# [1338 rows x 3 columns]

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()

for i in cat.columns:
  cat[i]= label_encoder.fit_transform(cat[i])
cat
# Out:
#       sex  smoker  region
# Id
# 1       0       1       3
# 2       1       0       2
# 3       1       0       2
# 4       1       0       1
# 5       1       0       1
# ...   ...     ...     ...
# 1334    1       0       1
# 1335    0       0       0
# 1336    0       0       2
# 1337    0       0       3
# 1338    0       1       1
#
# [1338 rows x 3 columns]

# %% [markdown]
# ## Numeric Features
#
#
# ```
# # from sklearn.preprocessing import StandardScaler
#
# scaler = StandardScaler()
# df[columnname] = scaler.fit_transform(df[[columnname]])
# ```

# %%
Num = df.select_dtypes(exclude = object)
Num
Y = Num.pop('Cost')

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
Num['bmi'] = scaler.fit_transform(Num[['bmi']])

# %% [markdown]
# ## Combining The Data

# %%
X = pd.concat([cat,Num], axis = 1)
X
# Out:
#       sex  smoker  region  age       bmi  children
# Id
# 1       0       1       3   19 -0.453320         0
# 2       1       0       2   18  0.509621         1
# 3       1       0       2   28  0.383307         3
# 4       1       0       1   33 -1.305531         0
# 5       1       0       1   32 -0.292556         0
# ...   ...     ...     ...  ...       ...       ...
# 1334    1       0       1   50  0.050297         3
# 1335    0       0       0   18  0.206139         0
# 1336    0       0       2   18  1.014878         0
# 1337    0       0       3   21 -0.797813         0
# 1338    0       1       1   61 -0.261388         0
#
# [1338 rows x 6 columns]

# %% [markdown]
# # Modeling

# %% [markdown]
# Linear Regression Formula:
#
# ```
# y = b0 + b1x1 + b2x2 + ... + bpxp + ε
# ```
#
#
#
#
#
#
# where:
#
# 1. y is the dependent variable
# 2. x1, x2, ..., xp are the independent variables
# 3. b0 is the y-intercept
# 4. b1, b2, ..., bp are the regression coefficients
# 5. ε is the error term

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2)

# Fit the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
# Predict the values
rmse = mean_squared_error(y_test, y_pred)
print('RMSE:', (rmse))
# Out:
# RMSE: 37275351.47577545

# %%
input = x_train.iloc[0].tolist()
orignal_error = y_train.iloc[0].tolist()
print(orignal_error)
# Out:
# 3556.9223

# %%
 x_train.iloc[0].tolist()
# Out:
# [0.0, 0.0, 1.0, 28.0, 0.6736655770497719, 0.0]

# %%
y_pred1 = model.predict([x_train.iloc[0]])
Predicted_error = y_pred1.tolist()[0]
print(f"Error rate is {orignal_error - Predicted_error}")
# Out:
# Error rate is -2836.885936179422
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names

# %%
plt.scatter(y_pred,y_test)
plt.xlabel('True values (expenses)')
plt.ylabel('Predictions (expenses)')
lims = [0, 50000]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims,lims)
plt.title("Errors")
# Out:
# Text(0.5, 1.0, 'Errors')

# %%
coef = model.coef_
coef
# Out:
# array([  130.53851238, 24038.29443775,  -308.43935572,   259.05132767,
#         1961.55762982,   463.93246418])

# %% [markdown]
# ## Decision Tree
#
# The DecisionTree Regressor builds a tree-like structure to predict continuous numerical values. It partitions the data based on feature values and computes the average of target values in leaf nodes to make predictions. Proper tuning of hyperparameters is essential to prevent overfitting and ensure optimal performance.
#
#
#
# ```
# # Prediction = Average(Target Values in Leaf Node)
# ```

# %%
from sklearn.tree import DecisionTreeRegressor


model = DecisionTreeRegressor(max_depth =  6, min_samples_leaf= 1 )


model.fit(x_train, y_train)

y_pred = model.predict(x_test)


rmse = mean_squared_error(y_test, y_pred)
print('RMSE:',rmse)
# Out:
# RMSE: 27110223.409848668

# %%
input = x_train.iloc[0].tolist()
orignal_error = y_train.iloc[0].tolist()
print(orignal_error)
# Out:
# 3556.9223

# %%
x_train
# Out:
#       sex  smoker  region  age       bmi  children
# Id
# 48      0       0       1   28  0.673666         0
# 1002    1       1       3   24  0.334094         0
# 91      0       0       2   21  1.447956         0
# 1045    1       0       0   55  0.751587         1
# 351     0       0       1   57 -1.227610         0
# ...   ...     ...     ...  ...       ...       ...
# 915     1       0       1   33 -0.993847         2
# 387     0       0       2   58  1.375776         0
# 1007    1       0       0   28 -0.230220         2
# 15      1       1       2   27  1.881033         0
# 928     0       0       3   57 -1.732867         1
#
# [1070 rows x 6 columns]

# %%
input
# Out:
# [0.0, 0.0, 1.0, 28.0, 0.6736655770497719, 0.0]

# %%
y_pred1 = model.predict([input])
Predicted_error = y_pred1.tolist()[0]
print(f"Error rate is {orignal_error - Predicted_error}")
# Out:
# Error rate is -1218.8304638461523
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning:
#
# X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names

# %%
plt.scatter(y_pred,y_test)
plt.xlabel('True values (expenses)')
plt.ylabel('Predictions (expenses)')
lims = [0, 50000]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims,lims)
plt.title("Errors")
# Out:
# Text(0.5, 1.0, 'Errors')

# %%
from sklearn import tree
a = tree.plot_tree(model, filled=True)
plt.rcParams['figure.figsize'] = [10,10]
plt.title("Visualiing Tree")
# Out:
# Text(0.5, 1.0, 'Visualiing Tree')

# %% [markdown]
# ## Saving model

# %%
import pickle
filename = 'finalized_model.sav'
pickle.dump(model, open(filename, 'wb'))

# some time later...

# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.predict(x_test)
rmse = mean_squared_error(y_test, result)
print('RMSE:',rmse)
# Out:
# RMSE: 27110223.409848668
